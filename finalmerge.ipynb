# %%
import pandas as pd
import datetime
import pandas as pd
from sklearn.linear_model import LinearRegression
import statsmodels.api as sm
import numpy as np
from matplotlib import pyplot as plt

# %%
fund=pd.read_csv("fund.csv")
complexity=pd.read_csv("complexity.csv")
complexity['Year']=complexity['Date']
dfmerge = pd.merge(fund, complexity, on=['Year', 'Ticker'])
dfmerge = dfmerge.dropna(subset=['Year', 'Ticker','TDTA', 'AP_TOV', 'Inv_TOV', 'ol', 'AR_TOV', 'ROA', 'CFM','btm','GPM','Beta'])
dfmerge.reset_index(drop=True, inplace=True)
dfmerge
# Out:
#       tic       ap        at    bkvlps      cogs   ebitda        gp     invt  \
# 0    AAPL  22367.0  207000.0  137.3968   99849.0  55756.0   71061.0   1764.0
# 1    AAPL  30196.0  231839.0   19.0153  104312.0  60449.0   78483.0   2111.0
# 2    AAPL  35490.0  290479.0   21.3946  129589.0  81730.0  104126.0   2349.0
# 3    AAPL  37294.0  321686.0   24.0339  121576.0  69276.0   93515.0   2132.0
# 4    AAPL  46236.0  338516.0   20.3653  150482.0  75230.0  109692.0   4106.0
# ..    ...      ...       ...       ...       ...      ...       ...      ...
# 192   WMT  37415.0  204751.0   23.5865  349199.0  34140.0  125060.0  44858.0
# 193   WMT  41433.0  198825.0   25.5243  351176.0  29594.0  130978.0  43046.0
# 194   WMT  46092.0  204522.0   26.3784  362867.0  29182.0  133918.0  43783.0
# 195   WMT  47060.0  219295.0   25.1897  374623.0  30149.0  137106.0  44269.0
# 196   WMT  46973.0  236495.0   26.3616  383618.0  30139.0  137808.0  44435.0
#
# ...
